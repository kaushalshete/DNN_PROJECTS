# %%
# NAME : KAUSHAL SHETE
# PRN : 20220802168
# BATCH : DS-1
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax' )
])
# Out:
# C:\Users\asus\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8738 - loss: 0.4321
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 966us/step - accuracy: 0.9649 - loss: 0.1194
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 978us/step - accuracy: 0.9763 - loss: 0.0771
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 987us/step - accuracy: 0.9839 - loss: 0.0527
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 977us/step - accuracy: 0.9878 - loss: 0.0404

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.9743 - loss: 0.0878
# Test accuracy: 0.9768999814987183

# %%
plt.imshow(x_test[0], cmap=plt.cm.binary)
plt.show()

# %%
plt.imshow(x_test[1], cmap=plt.cm.binary)
plt.show()

# %%
plt.imshow(x_test[8], cmap=plt.cm.binary)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(x_test[0], cmap=plt.cm.binary)
plt.show()
print(6000)
# Out:
# 6000

# %%
import matplotlib.pyplot as plt
plt.imshow(x_test[0], cmap=plt.cm.binary)
plt.show()
actual_label = y_test[0]
predicted_label = model.predict(x_test[0].reshape(1, 28, 28, 1))
predicted_label = predicted_label.argmax(axis=1)
print(f"Actual Label: {actual_label}")
print(f"Predicted Label: {predicted_label[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Actual Label: 7
# Predicted Label: 7

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt

# Assuming your model training code is in previous cells, and it's named 'model':

# Make a prediction (5th data point)
prediction = model.predict(x_test[4].reshape(1, 28, 28, 1))  # Reshape to (1, 28, 28, 1) for the model
predicted_label = np.argmax(prediction)
actual_label = y_test[4]  # Change index to 4

# Display the 5th image and prediction
plt.imshow(x_test[4], cmap=plt.cm.binary)  # Change index to 4
plt.show()
print(f"Actual label: {actual_label}")  # Fix missing f-string
print(f"Predicted label: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Actual label: 4
# Predicted label: 4

# %%
# NAME : KALPESH YASHWANT PATIL
# PRN : 20220802190
# BATCH : DS-1

pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
